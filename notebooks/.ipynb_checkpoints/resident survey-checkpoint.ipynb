# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hub_nash=pd.read_csv('../data/hub_requests.csv')
# Out:
# /Users/nicolemuldowney/opt/anaconda3/envs/geo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
res_survey = pd.read_csv('../data/metro_resident_survey.csv')
#Metro Resident Survey data from: https://data.nashville.gov/General-Government/Metro-Resident-Survey-Responses/nux7-cwab/data

# %%
res_survey.head()
# Out:
#    Period  Start Date    End Date  ZIP Code           Service District  \
# 0  2018Q2  06/21/2018  07/16/2018     37208    Urban Services District
# 1  2018Q2  06/21/2018  07/16/2018     37211    Urban Services District
# 2  2018Q2  06/21/2018  07/16/2018     37208    Urban Services District
# 3  2018Q2  06/21/2018  07/16/2018     37203    Urban Services District
# 4  2018Q1  02/01/2018  03/06/2018     37138  General Services District
#
#   Quality of Life Overall Feeling of Safety Neighborhood Safety  \
# 0         Neutral                   Neutral             Neutral
# 1       Satisfied                 Satisfied           Satisfied
# 2  Very Satisfied                   Neutral           Satisfied
# 3       Satisfied            Very Satisfied           Satisfied
# 4       Satisfied                 Satisfied           Satisfied
#
#   City Appearance Neighborhood Appearance  ... Race / Ethnicity - Black  \
# 0         Neutral               Satisfied  ...                      Yes
# ...

# %%
res_survey.columns
# Out:
# Index(['Period', 'Start Date', 'End Date', 'ZIP Code', 'Service District',
#        'Quality of Life', 'Overall Feeling of Safety', 'Neighborhood Safety',
#        'City Appearance', 'Neighborhood Appearance',
#        ...
#        'Race / Ethnicity - Black', 'Race / Ethnicity - Hispanic',
#        'Race / Ethnicity - Asian or Pacific Islander',
#        'Race / Ethnicity - Native American or Alaskan Native',
#        'Race / Ethnicity - Other', 'Race / Ethnicity - Other Definition',
#        'Total Annual Household Income', 'Age', 'Gender Identity',
#        'Education Attained'],
#       dtype='object', length=181)

# %%
#drop some columns to clean data/ focus on what columns are needed for analysis
res_survey=res_survey.drop(columns= ['Race / Ethnicity -- Asian or Pacific Islander'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-bb184a0c0e8f> in <module>
#       1 #drop some columns to clean data/ focus on what columns are needed for analysis
# ----> 2 res_survey=res_survey.drop(columns= ['Race / Ethnicity -- Asian or Pacific Islander'])
#
# ~/opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
res_survey['Quality of Life'].unique()
# Out:
# array(['Neutral', 'Satisfied', 'Very Satisfied', 'Very Dissatisfied',
#        'Dissatisfied', "Don't Know"], dtype=object)

# %%
high_quality = res_survey.loc[(res_survey['Quality of Life'] == 'Very Satisfied')]
high_quality
# Out:
#       Start Date    End Date  ZIP Code           Service District  \
# 2     06/21/2018  07/16/2018     37208    Urban Services District
# 5     06/21/2018  07/16/2018     37207    Urban Services District
# 11    06/21/2018  07/16/2018     37211    Urban Services District
# 12    06/21/2018  07/16/2018     37207    Urban Services District
# 13    06/21/2018  07/16/2018     37204    Urban Services District
# ...          ...         ...       ...                        ...
# 2141  02/13/2019  03/22/2019     37218    Urban Services District
# 2143  02/13/2019  03/22/2019     37207    Urban Services District
# 2145  02/13/2019  03/22/2019     37115  General Services District
# 2149  02/13/2019  03/22/2019     37205    Urban Services District
# 2150  02/13/2019  03/22/2019     37215    Urban Services District
#
#      Quality of Life Overall Feeling of Safety Neighborhood Safety  \
# 2     Very Satisfied                   Neutral           Satisfied
# ...
