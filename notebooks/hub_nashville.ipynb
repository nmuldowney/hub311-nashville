# %% [markdown]
# # hubNashville (311) Service Requests

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
hub = pd.read_csv('../class_data/hub_requests.csv')
hub.head()
# Out:
# /Users/nicolemuldowney/opt/anaconda3/envs/geo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Request #  Status                Request Type  \
# 0     113016  Closed   Trash, Recycling & Litter
# 1     126185  Closed  Streets, Roads & Sidewalks
# 2     119344  Closed   Trash, Recycling & Litter
# 3     127752  Closed   Trash, Recycling & Litter
# 4     113477  Closed   Trash, Recycling & Litter
#
#                      Subrequest Type            Additional Subrequest Type  \
# 0                       Cart Service    Trash - Request an Additional Cart
# 1          Blocking the Right of Way                                   NaN
# 2                 Damage to Property                         Trash Service
# 3       New Service/Activate Service  New Construction Residential Recycle
# ...

# %%
hub.tail()
# Out:
#         Request #  Status                Request Type  \
# 348666       2699  Closed  Streets, Roads & Sidewalks
# 348667       2214  Closed   Trash, Recycling & Litter
# 348668        163  Closed   Trash, Recycling & Litter
# 348669       3202  Closed  Streets, Roads & Sidewalks
# 348670       1237  Closed  Streets, Roads & Sidewalks
#
#                            Subrequest Type  \
# 348666                            Potholes
# 348667                        Cart Service
# 348668  Missed Pickup - Trash Cart Service
# 348669          Overgrowth on right of way
# 348670          Overgrowth on right of way
#
#                   Additional Subrequest Type      Date / Time Opened  \
# 348666                               Roadway  07/26/2017 02:54:00 PM
# 348667         Trash - Report a Damaged Cart  07/24/2017 04:58:00 PM
# 348668  Trash - Curbside/Alley Missed Pickup  07/17/2017 07:12:00 AM
# 348669                               Roadway  07/28/2017 10:07:00 AM
# ...

# %%
hub.shape
# Out:
# (348671, 21)

# %%
hub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348671 entries, 0 to 348670
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Request #                   348671 non-null  int64
#  1   Status                      348671 non-null  object
#  2   Request Type                348603 non-null  object
#  3   Subrequest Type             338024 non-null  object
#  4   Additional Subrequest Type  180510 non-null  object
#  5   Date / Time Opened          348671 non-null  object
#  6   Date / Time Closed          338424 non-null  object
#  7   Request Origin              348671 non-null  object
#  8   System of Origin ID         26398 non-null   object
#  9   Contact Type                26129 non-null   object
#  10  Preferred Language          0 non-null       float64
#  11  State Issue                 348671 non-null  bool
#  12  Parent Request              3589 non-null    float64
# ...

# %%
hub['Request Type'].value_counts()
# Out:
# Trash, Recycling & Litter     145146
# Streets, Roads & Sidewalks     84830
# Quick Requests                 64659
# Property Violations            20651
# Public Safety                   9733
# COVID-19                        5246
# Other                           4814
# Electric & Water General        4354
# Transit                         3692
# Hands On Volunteers             2637
# Permits                         1322
# Parks                           1070
# Planning & Zoning                250
# Storm Relief                     167
# Education & Libraries             22
# Workforce & Jobs                   8
# Public Records Request             2
# Name: Request Type, dtype: int64

# %%
hub['Subrequest Type'].value_counts()
# Out:
# Quick Requests                             54141
# Cart Service                               38339
# Missed Pickup - Trash Cart Service         26338
# Missed Pickup - Recycle Cart Service       19381
# File a Trash or Recycling Complaint        16511
#                                            ...
# Pharmaceutical Disposal                        1
# Sign Signal Repairs                            1
# Request Fire Truck for Event Appearance        1
# Opportunity Now                                1
# Request to Council Member                      1
# Name: Subrequest Type, Length: 185, dtype: int64

# %%
hub['Request Origin'].value_counts()
# Out:
# Phone                     244656
# hubNashville Community     88649
# Mobile App                 13051
# Email                       1721
# Mayor's Office               372
# Council Member               129
# Council's Website             50
# Walk-In                       18
# Mayor's Website                8
# In Person at Event             6
# Social Media                   5
# USPS Letter                    5
# OEM Case                       1
# Name: Request Origin, dtype: int64

# %%
hub['Status'].unique()
# Out:
# array(['Closed', 'Assigned', 'New', 'In Progress', 'Transferred',
#        'Denied', 'In Process', 'On Hold', 'Completed', 'Escalated'],
#       dtype=object)

# %%
denied = hub.loc[hub['Status']=='Denied']
denied
# Out:
#        Request #  Status Request Type   Subrequest Type  \
# 23776     104776  Denied      Permits  Building Permits
# 41426      93932  Denied        Other             Other
#
#       Additional Subrequest Type  Date / Time Opened  Date / Time Closed  \
# 23776                        NaN 2018-10-01 12:02:00 2018-10-02 09:33:00
# 41426                        NaN 2018-08-30 09:02:00 2018-09-04 16:00:00
#
#                Request Origin System of Origin ID Contact Type  ...  \
# 23776  hubNashville Community                 NaN          NaN  ...
# 41426  hubNashville Community                 NaN          NaN  ...
#
#        Parent Request  Closed When Created  \
# 23776             NaN                 True
# 41426             NaN                 True
#
#                                                  Address       City  \
# 23776  555 Donelson Pike, Nashville, TN 37214, United...  NASHVILLE
# 41426         2310 12th Avenue South, Nashville, TN, USA  NASHVILLE
#
# ...

# %%
hub['ZIP'].value_counts()
# Out:
# 37013.0     19589
# 37211.0     18889
# 37209.0     17605
# 37206.0     15716
# 37207.0     14325
#             ...
# 37663.0         1
# 37363.0         1
# 37036.0         1
# 37040.0         1
# 372515.0        1
# Name: ZIP, Length: 97, dtype: int64

# %%
hub.isnull().sum()
# Out:
# Request #                          0
# Status                             0
# Request Type                      68
# Subrequest Type                10647
# Additional Subrequest Type    168161
# Date / Time Opened                 0
# Date / Time Closed             10247
# Request Origin                     0
# System of Origin ID           322273
# Contact Type                  322542
# Preferred Language            348671
# State Issue                        0
# Parent Request                345082
# Closed When Created                0
# Address                        63613
# City                           67900
# Council District               68097
# ZIP                            67996
# Latitude                       64483
# Longitude                      64483
# Mapped Location                64483
# dtype: int64

# %%
hub['Request Type'].value_counts()[:10].plot(kind='barh',color='lightblue')
plt.xlabel('Number of Requests')
plt.ylabel('Request Type')
plt.title('Nashville Hub Requests');

# %%
hub['Subrequest Type'].value_counts()[:10].plot(kind='barh',color='pink')
plt.xlabel('Number of Requests')
plt.ylabel('Subrequest Type')
plt.title('Nashville Hub Subrequests');

# %%
request_count = hub['Request Type'].value_counts()
request_count
# Out:
# Trash, Recycling & Litter     145146
# Streets, Roads & Sidewalks     84830
# Quick Requests                 64659
# Property Violations            20651
# Public Safety                   9733
# COVID-19                        5246
# Other                           4814
# Electric & Water General        4354
# Transit                         3692
# Hands On Volunteers             2637
# Permits                         1322
# Parks                           1070
# Planning & Zoning                250
# Storm Relief                     167
# Education & Libraries             22
# Workforce & Jobs                   8
# Public Records Request             2
# Name: Request Type, dtype: int64

# %%
hub['Date / Time Opened'] = pd.to_datetime(hub['Date / Time Opened'], errors='coerce')
hub['Date / Time Closed'] = pd.to_datetime(hub['Date / Time Closed'], errors ='coerce')
hub.head()
# Out:
#    Request #  Status                Request Type  \
# 0     113016  Closed   Trash, Recycling & Litter
# 1     126185  Closed  Streets, Roads & Sidewalks
# 2     119344  Closed   Trash, Recycling & Litter
# 3     127752  Closed   Trash, Recycling & Litter
# 4     113477  Closed   Trash, Recycling & Litter
#
#                      Subrequest Type            Additional Subrequest Type  \
# 0                       Cart Service    Trash - Request an Additional Cart
# 1          Blocking the Right of Way                                   NaN
# 2                 Damage to Property                         Trash Service
# 3       New Service/Activate Service  New Construction Residential Recycle
# 4  Backdoor Trash or Recycle Waivers   Request Recycling Disability Waiver
#
#    Date / Time Opened  Date / Time Closed Request Origin  \
# 0 2018-10-30 13:47:00 2019-03-05 21:35:00          Phone
# 1 2018-12-28 13:04:00 2018-12-28 13:04:00          Phone
# ...

# %%
print(hub['Date / Time Closed'].min())
print(hub['Date / Time Closed'].max())
# Out:
# 2017-07-17 08:34:00
# 2020-05-13 05:02:53

# %%
print(hub['Date / Time Opened'].min())
print(hub['Date / Time Opened'].max())
# Out:
# 2017-07-17 03:30:00
# 2020-05-13 05:02:53

# %%
#where State Issue = True

# %%
state_issues = hub.loc[hub['State Issue'] == True]
state_issues.head()
# Out:
#         Request #  Status                Request Type Subrequest Type  \
# 45252       91917  Closed                     Transit    State Routes
# 307253     148877  Closed                     Transit    State Routes
# 325498     143401  Closed                     Transit    State Routes
# 346250        676  Closed                     Transit    State Routes
# 348096        365  Closed  Streets, Roads & Sidewalks  Paving Request
#
#        Additional Subrequest Type  Date / Time Opened  Date / Time Closed  \
# 45252                         NaN 2018-08-21 19:52:00 2018-08-22 14:22:00
# 307253                        NaN 2019-02-28 23:50:00 2019-03-04 19:52:00
# 325498                        NaN 2019-02-18 19:17:00 2019-02-22 17:53:00
# 346250                        NaN 2017-07-18 15:51:00 2017-10-11 16:24:00
# 348096   Request Road to be Paved 2017-07-17 12:07:00 2017-07-17 12:08:00
#
#                 Request Origin System of Origin ID Contact Type  ...  \
# ...

# %%
not_state_issues = hub.loc[hub['State Issue'] == False]
not_state_issues.shape
# Out:
# (348665, 21)

# %%
address_counts = hub['Address'].value_counts()
address_counts
# Out:
# 215 6th Ave N                                        482
# 210 Anne Dallas Dudley Blvd                          443
# I-24                                                 217
# 215 6th Ave N, Nashville, TN 37219, United States    191
# I-65                                                 189
#                                                     ...
# 1008 TUCKAHOE DR                                       1
# 100 Centerview Dr                                      1
# Arbor Pointe Wy & Arbor Pointe Cv                      1
# Wedgewood  & 21st Ave s                                1
# 105 McLendon Ct                                        1
# Name: Address, Length: 148093, dtype: int64

# %%
top_address = hub.loc[hub['Address'] == '215 6th Ave N']
top_address
# Out:
#         Request #  Status                Request Type  \
# 89         121106  Closed  Streets, Roads & Sidewalks
# 117        121755  Closed  Streets, Roads & Sidewalks
# 682        125686  Closed                       Parks
# 1330       116618  Closed  Streets, Roads & Sidewalks
# 1496       125757  Closed   Trash, Recycling & Litter
# ...           ...     ...                         ...
# 327076     142654  Closed         Property Violations
# 327479     131385  Closed                       Other
# 327608     132052  Closed                     Transit
# 327892     135910  Closed         Property Violations
# 327910     130940  Closed  Streets, Roads & Sidewalks
#
#                        Subrequest Type Additional Subrequest Type  \
# 89      Shared Scooter and Bike Issues          Scooter Complaint
# 117     Shared Scooter and Bike Issues          Scooter Complaint
# 682                Maintenance Request                        NaN
# ...

# %%
top_address['Subrequest Type'].value_counts()
# Out:
# Other                                 59
# Maintenance Request                   49
# Shared Scooter and Bike Issues        46
# Junk and Debris                       22
# Tall Grass and Weeds                  18
#                                       ..
# Short Term Rental Complaint            1
# Residential Dumpster Services          1
# Request Repair to Private Property     1
# Planning Request                       1
# Animal Welfare Concern                 1
# Name: Subrequest Type, Length: 74, dtype: int64

# %%
scooter = hub.loc[hub['Subrequest Type'] == 'Shared Scooter and Bike Issues']
scooter
# Out:
#         Request #  Status                Request Type  \
# 89         121106  Closed  Streets, Roads & Sidewalks
# 117        121755  Closed  Streets, Roads & Sidewalks
# 369        121145  Closed  Streets, Roads & Sidewalks
# 760        123832  Closed  Streets, Roads & Sidewalks
# 848        118517  Closed  Streets, Roads & Sidewalks
# ...           ...     ...                         ...
# 326562     137020  Closed  Streets, Roads & Sidewalks
# 326570     140483  Closed  Streets, Roads & Sidewalks
# 326642     140261  Closed  Streets, Roads & Sidewalks
# 327574     145204  Closed  Streets, Roads & Sidewalks
# 327819     136623  Closed  Streets, Roads & Sidewalks
#
#                        Subrequest Type Additional Subrequest Type  \
# 89      Shared Scooter and Bike Issues          Scooter Complaint
# 117     Shared Scooter and Bike Issues          Scooter Complaint
# 369     Shared Scooter and Bike Issues          Scooter Complaint
# ...

# %%
top_address['Subrequest Type'].value_counts()
# Out:
# Other                                 59
# Maintenance Request                   49
# Shared Scooter and Bike Issues        46
# Junk and Debris                       22
# Tall Grass and Weeds                  18
#                                       ..
# Short Term Rental Complaint            1
# Residential Dumpster Services          1
# Request Repair to Private Property     1
# Planning Request                       1
# Animal Welfare Concern                 1
# Name: Subrequest Type, Length: 74, dtype: int64

# %%
top_address2 = hub.loc[hub['Address'] == '210 Anne Dallas Dudley Blvd']
top_address2['Subrequest Type'].value_counts()
# Out:
# COVID-19 Violations                   58
# Missed Pickup - Trash Cart Service    31
# Other                                 28
# Maintenance Request                   18
# Potholes                              18
#                                       ..
# Paving Request                         1
# Inlet Maintenance                      1
# Short Term Rental Complaint            1
# Traffic Engineering                    1
# Fence Complaints                       1
# Name: Subrequest Type, Length: 75, dtype: int64

# %%
covid = hub.loc[hub['Subrequest Type'] == 'COVID-19 Violations']
covid
# Out:
#         Request #  Status Request Type      Subrequest Type  \
# 4562       339424  Closed     COVID-19  COVID-19 Violations
# 4971       348304  Closed     COVID-19  COVID-19 Violations
# 24756      339754  Closed     COVID-19  COVID-19 Violations
# 28885      339739  Closed     COVID-19  COVID-19 Violations
# 96872      348312  Closed     COVID-19  COVID-19 Violations
# ...           ...     ...          ...                  ...
# 144610     364797  Closed     COVID-19  COVID-19 Violations
# 144619     364785     New     COVID-19  COVID-19 Violations
# 144630     364796  Closed     COVID-19  COVID-19 Violations
# 144640     364714     New     COVID-19  COVID-19 Violations
# 144642     364664     New     COVID-19  COVID-19 Violations
#
#        Additional Subrequest Type  Date / Time Opened  Date / Time Closed  \
# 4562          COVID-19 Violations 2020-04-04 20:18:05 2020-04-09 14:20:19
# 4971                          NaN 2020-04-17 21:30:20 2020-04-21 14:07:48
# ...

# %%
#to see how long requests take and then add timeline to a column in DF

# %%
timeline = hub['Date / Time Closed'] - hub['Date / Time Opened']
timeline.sort_values(ascending = False)
# Out:
# 345555   885 days 00:41:00
# 344186   873 days 02:22:00
# 337919   858 days 21:32:00
# 336809   858 days 05:06:00
# 344067   851 days 14:46:00
#                 ...
# 327502                 NaT
# 327570                 NaT
# 327597                 NaT
# 327959                 NaT
# 330574                 NaT
# Length: 348671, dtype: timedelta64[ns]

# %%
hub['Timeline'] = timeline
hub.head()
# Out:
#    Request #  Status                Request Type  \
# 0     113016  Closed   Trash, Recycling & Litter
# 1     126185  Closed  Streets, Roads & Sidewalks
# 2     119344  Closed   Trash, Recycling & Litter
# 3     127752  Closed   Trash, Recycling & Litter
# 4     113477  Closed   Trash, Recycling & Litter
#
#                      Subrequest Type            Additional Subrequest Type  \
# 0                       Cart Service    Trash - Request an Additional Cart
# 1          Blocking the Right of Way                                   NaN
# 2                 Damage to Property                         Trash Service
# 3       New Service/Activate Service  New Construction Residential Recycle
# 4  Backdoor Trash or Recycle Waivers   Request Recycling Disability Waiver
#
#    Date / Time Opened  Date / Time Closed Request Origin  \
# 0 2018-10-30 13:47:00 2019-03-05 21:35:00          Phone
# 1 2018-12-28 13:04:00 2018-12-28 13:04:00          Phone
# ...

# %%
hub.sort_values('Timeline',ascending = False).head(15)
# Out:
#         Request #  Status                Request Type  \
# 345555       3241  Closed  Streets, Roads & Sidewalks
# 344186       5458  Closed  Streets, Roads & Sidewalks
# 337919       4702  Closed  Streets, Roads & Sidewalks
# 336809       4613  Closed  Streets, Roads & Sidewalks
# 344067       6150  Closed  Streets, Roads & Sidewalks
# 347606        797  Closed  Streets, Roads & Sidewalks
# 339934      17098  Closed  Streets, Roads & Sidewalks
# 341951       9145  Closed         Property Violations
# 343275      19686  Closed  Streets, Roads & Sidewalks
# 92460       25424  Closed  Streets, Roads & Sidewalks
# 83100       28692  Closed  Streets, Roads & Sidewalks
# 91715       31085  Closed  Streets, Roads & Sidewalks
# 85264       24075  Closed  Streets, Roads & Sidewalks
# 84946       39786  Closed               Public Safety
# 79665       42789  Closed  Streets, Roads & Sidewalks
#
#                     Subrequest Type Additional Subrequest Type  \
# ...

# %%
sns.boxplot(y=hub.Timeline, x = hub.City)
#plt.title('timeline per city');
#plt.xlabel('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-bc30d1a8aa94> in <module>
# ----> 1 sns.boxplot(y=hub.Timeline, x = hub.City)
#       2 #plt.title('timeline per city');
#       3 #plt.xlabel('')
#
# ~/opt/anaconda3/envs/geo/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     kwargs.update(dict(whis=whis))
#    2240
# -> 2241     plotter.plot(ax, kwargs)
#    2242     return ax
#    2243
#
# ~/opt/anaconda3/envs/geo/lib/python3.7/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     537     def plot(self, ax, boxplot_kws):
#     538         """Make the plot."""
# --> 539         self.draw_boxplot(ax, boxplot_kws)
#     540         self.annotate_axes(ax)
# ...
